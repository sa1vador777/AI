# %% [markdown]
# # Лабораторная работа 2. Визуальный анализ данных.

# %% [markdown]
# **Выполнил**: _Бересланов Рамазан_
#
# **Группа**: ПИЖ-б-о-22-1

# %% [markdown]
# ## Подключение библиотек

# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# ## Загрузка данных

# %%
data_path = '/content/drive/MyDrive/Colab Notebooks/ИИ/lr_2/telecom_churn.csv'
data = pd.read_csv(data_path)
data.head(10)
# Out:
#   State  Account length  Area code International plan Voice mail plan  \
# 0    KS             128        415                 No             Yes
# 1    OH             107        415                 No             Yes
# 2    NJ             137        415                 No              No
# 3    OH              84        408                Yes              No
# 4    OK              75        415                Yes              No
# 5    AL             118        510                Yes              No
# 6    MA             121        510                 No             Yes
# 7    MO             147        415                Yes              No
# 8    LA             117        408                 No              No
# 9    WV             141        415                Yes             Yes
#
#    Number vmail messages  Total day minutes  Total day calls  \
# 0                     25              265.1              110
# 1                     26              161.6              123
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3333 entries, 0 to 3332
# Data columns (total 20 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   State                   3333 non-null   object
#  1   Account length          3333 non-null   int64
#  2   Area code               3333 non-null   int64
#  3   International plan      3333 non-null   object
#  4   Voice mail plan         3333 non-null   object
#  5   Number vmail messages   3333 non-null   int64
#  6   Total day minutes       3333 non-null   float64
#  7   Total day calls         3333 non-null   int64
#  8   Total day charge        3333 non-null   float64
#  9   Total eve minutes       3333 non-null   float64
#  10  Total eve calls         3333 non-null   int64
#  11  Total eve charge        3333 non-null   float64
#  12  Total night minutes     3333 non-null   float64
#  13  Total night calls       3333 non-null   int64
# ...

# %% [markdown]
# ## Одиночные признаки

# %% [markdown]
# ### Количественные признаки

# %%
data.columns
# Out:
# Index(['State', 'Account length', 'Area code', 'International plan',
#        'Voice mail plan', 'Number vmail messages', 'Total day minutes',
#        'Total day calls', 'Total day charge', 'Total eve minutes',
#        'Total eve calls', 'Total eve charge', 'Total night minutes',
#        'Total night calls', 'Total night charge', 'Total intl minutes',
#        'Total intl calls', 'Total intl charge', 'Customer service calls',
#        'Churn'],
#       dtype='object')

# %%
# Применение pandas для визуализации данных
# Pandas работает как настройка над matplotlib
data['Customer service calls'].hist();

# %%
# использование Seaborn
# Построение диаграммы типа "ящик с усами"
# по диаграмме можно определить медиану, квартили,
# интерквартильный размах, выбросы
sns.boxplot(data['Total day minutes']);

# %%
top_data = data[['State','Total day minutes']]
top_data = top_data.groupby('State').sum()
top_data = top_data.sort_values('Total day minutes',ascending=False)
top_data = top_data[:3].index.values
sns.boxplot(y='State',
            x='Total day minutes',
            data=data[data.State.isin(top_data)], palette='Set2');
# Out:
# <ipython-input-41-add119f26021>:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(y='State',

# %%
plt.bar(data.index, data['State'])
plt.show()

# %%
hist = data['Total day minutes'].value_counts()
plt.bar(hist.index, hist);

# %%
# построение гистограммы для нескольких признаков
feats=[f for f in data.columns if 'charge' in f]
data[feats].hist(figsize=(5,5));

# %% [markdown]
# ## **Категориальные** признаки

# %%
# определение первых n "популярных" штатов
# data['State'].value_counts().head(10)
hist = data['State'].value_counts()
plt.bar(hist.index, hist);

# %%
# фактически бинарный признак
data['Churn'].value_counts()
# Out:
# False    2850
# True      483
# Name: Churn, dtype: int64

# %%
sns.countplot(data, x='Churn', palette=['blue', 'orange']);
# Out:
# <ipython-input-89-002f98920476>:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data, x='Churn', palette=['blue', 'orange']);

# %%
# гистограмма для всех штатов
sns.countplot(data, x='State', palette='husl');
# Out:
# <ipython-input-91-4eb02cb04949>:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data, x='State', palette='husl');

# %%
# гистограмма "популярных" штатов
sns.countplot(data[data['State'].isin(data['State'].value_counts().tail(5).index)], x='State', palette=['blue', 'orange', 'green', 'red', 'purple']);
# Out:
# <ipython-input-94-1c0aa93cd866>:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data[data['State'].isin(data['State'].value_counts().tail(5).index)], x='State', palette=['blue', 'orange', 'green', 'red', 'purple']);

# %% [markdown]
# ## Взаимосвязанные признаки

# %% [markdown]
# ### Количественный - количественный

# %%
# список колонок
data.columns
# Out:
# Index(['State', 'Account length', 'Area code', 'International plan',
#        'Voice mail plan', 'Number vmail messages', 'Total day minutes',
#        'Total day calls', 'Total day charge', 'Total eve minutes',
#        'Total eve calls', 'Total eve charge', 'Total night minutes',
#        'Total night calls', 'Total night charge', 'Total intl minutes',
#        'Total intl calls', 'Total intl charge', 'Customer service calls',
#        'Churn'],
#       dtype='object')

# %%
# Отбор числовых признаков, содержащих слово 'charge'
feats = [f for f in data.columns if 'charge' in f]
len(feats)
# feats=['Total day calls', 'Total day charge']
# Out:
# 4

# %%
# строим отдельные гистограммы
# для нескольких признаков
data[feats].hist(figsize=(5,5));

# %%
# Попарное распределение признаков
# Применение Seaborn
sns.pairplot(data[feats]);

# %% [markdown]
# Можно строить более сложные попарные распределения признаков

# %%
sns.pairplot(data[feats + ['Churn']], hue='Churn');

# %% [markdown]
# Использование matplotlib, подписей данных, заголовков Использование простейших пользовательских цветов

# %%
plt.scatter(data['Total day charge'],
            data['Total intl charge'],
            color='lightblue', edgecolors='blue')
plt.xlabel('Дневные начисление')
plt.ylabel('Международн. начисление')
plt.title('Распределение по 2 признакам');

# %%
# Раскрашивание данных
# Цвет в зависимости от ухода клиента
c = data['Churn'].map({False: 'lightblue', True: 'orange'})
edge_c = data['Churn'].map({False: 'blue', True: 'red'})
# Настройка графика
plt.scatter(data['Total day charge'], data['Total intl charge'],
            color=c, edgecolors=edge_c
           )
plt.xlabel('Дневные начисление')
plt.ylabel('Международн. начисление');

# %%
# Раскраска лояльных и ушедших клиентов,
# добавление легенды

# Ушедшие клиенты
data_churn = data[data['Churn']]
# Оставшиеся клиенты
data_loyal = data[~data['Churn']]

plt.scatter(data_churn['Total day charge'],
            data_churn['Total intl charge'],
            color='orange',
            edgecolors='red',
            label='Ушли'
           )
plt.scatter(data_loyal['Total day charge'],
            data_loyal['Total intl charge'],
            color='lightblue',
            edgecolors='blue',
            label='Остались'
           )
plt.xlabel('Дневные начисление')
plt.ylabel('Международн. начисление')
plt.title('Распределение клиентов')
plt.legend();

# %% [markdown]
# ## Корреляция признаков

# %%
# Применяется функция corr() из Pandas
data.corr()
# Out:
# <ipython-input-103-a28ca9997cfb>:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   data.corr()
#                         Account length  Area code  Number vmail messages  \
# Account length                1.000000  -0.012463              -0.004628
# Area code                    -0.012463   1.000000              -0.001994
# Number vmail messages        -0.004628  -0.001994               1.000000
# Total day minutes             0.006216  -0.008264               0.000778
# Total day calls               0.038470  -0.009646              -0.009548
# Total day charge              0.006214  -0.008264               0.000776
# Total eve minutes            -0.006757   0.003580               0.017562
# Total eve calls               0.019260  -0.011886              -0.005864
# ...

# %% [markdown]
# В реальных задачах анализ такой матрицы затруднен, необходимо или автоматизировать (скрипты), или визуализировать (графики)

# %%
sns.heatmap(data.corr(), cmap=plt.cm.PuBuGn);
# Out:
# <ipython-input-104-b9710ca2362c>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(data.corr(), cmap=plt.cm.PuBuGn);

# %% [markdown]
# ## Контрольные вопросы

# %% [markdown]
# 1. Какие инструментальные средства используются для организации рабочего места специалиста Data Science? **Ответ**: Для организации рабочего места специалиста Data Science используются такие инструменты, как Jupyter Notebook, PyCharm, Git, Docker, а также библиотеки для визуализации данных, например, Matplotlib и Seaborn.
#
# 2. Какие библиотеки Python используются для работы в области машинного обучения? Дайте краткую характеристику каждой библиотеки. **Ответ**: Основные библиотеки Python для работы в области машинного обучения включают NumPy (массивы и математические функции), Pandas (структуры данных и анализ данных), Scikit-learn (алгоритмы машинного обучения) и Matplotlib (визуализация данных).
#
# 3. Почему при реализации систем машинного обучения широкое распространение получили библиотеки Python? **Ответ**: Библиотеки Python для машинного обучения стали широко распространенными из-за их простоты использования, обширной документации, активной поддержки сообщества и открытого исходного кода.
#
# 4. Перечислите функции Python, которые были изучены в рамках данной лабораторной работы и которые используются для визуализации данных. **Ответ**: Функции Python для визуализации данных включают plot(), scatter(), bar(), hist(), pie() из библиотеки Matplotlib.
#
# 5. Какая библиотека Python предназначена для управления наборами данных: numpy, pandas, sklearn, opencv, matplotlib? **Ответ**: Для управления наборами данных используется библиотека Pandas.
#
# 6. Какая стратегия является нежелательной при обработке пропусков в данных?**Ответ**: Нежелательной стратегией при обработке пропусков в данных является б) удаление строк, содержащих пропуски в данных.
#
# 7. Обоснуйте ответ на следующую проблему предварительной обработки данных: имеется независимая категориальная переменная y, которая представляет собой категориальный признак, опеределнный на домене {C#, Java, Python, R}. Нужно ли применять к данному целевому признаку OneHotEncoder? **Ответ**: Да, к данному целевому признаку следует применить OneHotEncoder, так как он представляет неупорядоченные категориальные значения.
#
# 8. Поясните принцип разбиения набора данных на обучающую и тестовую выборку. Какое соотношение «тестовая:обучающая» наиболее оптимально: 20:80, 50:50, 25:75, 5:95, 40:30? **Ответ**: Набор данных разбивается на обучающую и тестовую выборку для обучения и проверки модели. Наиболее оптимальное соотношение "тестовая:обучающая" обычно составляет от 20:80 до 40:60.
#
# 9. Какой код лучше использовать при загрузке данных из csv-файла? **Ответ**: Лучше использовать код: а) dataset = read_csv(“data.csv”)
